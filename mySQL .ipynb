# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
divy = mysql.connector.connect(
  host="localhost",
  user="root",
  password="example@2023"
)

# %%
print(divy.is_connected())
# Out:
# True

# %%
cur = divy.cursor()
cur.execute("show databases")

for i in cur:
    print(i)
# Out:
# ('divyanshudb',)
# ('fsds_db',)
# ('ineuron',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('testing1',)

# %%
cur.execute("create database fsds_db")

# %%
cur.execute("use fsds_db")

# %%
cur.execute("create table fsds1(name varchar(40), roll int, mail_id varchar(40))")

# %%
cur.execute("select * from fsds1")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 cur.execute("select * from fsds1")
#
# File ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py:303, in CMySQLCursor.execute(self, operation, params, multi)
#     301 except (ProgrammingError, ReferenceError) as err:
#     302     raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 303 self._cnx.handle_unread_result()
#     305 stmt = ""
#     306 self.reset()
#
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:932, in CMySQLConnection.handle_unread_result(self, prepared)
#     930     self.consume_results()
#     931 elif unread_result:
# --> 932     raise InternalError("Unread result found")
#
# InternalError: Unread result found

# %%
cur.execute("create table if not exists ineuron.glass_data(`index` INT, RI FLOAT, Na FLOAT, Mg FLOAT, Al FLOAT, Si FLOAT, K FLOAT, Ca FLOAT,Ba FLOAT, Fe FLOAT,Class FLOAT )")

# %%
cur.execute("LOAD DATA INFILE 'data.txt'")
cur.execute("INTO TABLE ineuron.glass_data")
cur.execute("FIELDS TERMINATED BY ','")
cur.execute("LINES TERMINATED BY '\n'")
cur.execute("IGNORE 1 ROWS;")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:611, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     610         query = query.encode("utf-8")
# --> 611     self._cmysql.query(
#     612         query,
#     613         raw=raw,
#     614         buffered=buffered,
#     615         raw_as_string=raw_as_string,
#     616         query_attrs=self._query_attrs,
#     617     )
#     618 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ...

# %%
pip install pymysql

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}".format(user='root',pw=8904,host='localhost'))

# %%
engine.execute("create database if not exists ineuron")
engine.execute("create table if not exists ineuron.glass_data(`index` INT, RI FLOAT, Na FLOAT, Mg FLOAT, Al FLOAT, Si FLOAT, K FLOAT, Ca FLOAT, Ba FLOAT, Fe FLOAT,Class FLOAT )")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...
